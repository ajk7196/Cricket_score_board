# %% [markdown]
# <a href="https://colab.research.google.com/github/ajk7196/Cricket_score_board/blob/main/M1W3_Introduction_to_Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <u> Use only those concepts which have been taught till now </u>

# %% [markdown]
# ## Use the file company_sales_data.csv

# %%
import numpy as np
import pandas as pd

from datetime import datetime

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/MyDrive/data science/company_sales_data.csv'
df=pd.read_csv(file_path)

# %%
df.head(5)
# Out:
#    month_number  facecream  facewash  ...  moisturizer  total_units  total_profit
# 0             1       2500      1500  ...         1500        21100        211000
# 1             2       2630      1200  ...         1200        18330        183300
# 2             3       2140      1340  ...         1340        22470        224700
# 3             4       3400      1130  ...         1130        22270        222700
# 4             5       3600      1740  ...         1740        20960        209600
#
# [5 rows x 9 columns]

# %% [markdown]
# # <u>**Problem 1**</u>
#
# ### Plot the total profit across the months
#
# * X label name = Month Number
# * Y label name = Total profit

# %%
# Your code here
plt.plot(df['month_number'], df['total_profit'])
plt.xlabel('Month Number')
plt.ylabel('Total Profit')
plt.title('PROFIT ACROSS MONTHS')
# Out:
# Text(0.5, 1.0, 'PROFIT ACROSS MONTHS')

# %% [markdown]
# # <b><u>Problem 2 </u></b>
#
# ### Read face cream and facewash product sales data and show it using the bar chart. The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.

# %%
# Your code here

units_sold = df.groupby('month_number')['facecream', 'facewash']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
units_sold.plot(kind = 'bar')
plt.xlabel('MONTH')
plt.ylabel('SALES')
plt.title('MONTH VS SALES')
# Out:
# Text(0.5, 1.0, 'MONTH VS SALES')

# %% [markdown]
# # <b><u>Problem 3</u></b>
#
# ### Display the number of units sold per month for each product using multiline plots. (i.e. separate plotline for each product ).

# %%
plt.figure(figsize=(10,7.5))

products = ['facecream', 'facewash', 'toothpaste',	'bathingsoap',	'shampoo',	'moisturizer']
for item in products:
    plt.plot(df['month_number'],df[item], marker = '.', label = item)



plt.xlabel('MONTH')
plt.ylabel('SALES')
plt.title('SALES vs MONTH')
plt.legend()
plt.show()
# plt.xticks(df.month_number)
